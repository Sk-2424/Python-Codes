# %%
import pandas as pd

# %%
data = [[20,30],
       [40,50],
       [33,44],
       [67,89],
       [54,66],
       [78,99]]

# %%
ind = pd.MultiIndex.from_product([['a','b','c'],[2019,2020]])

# %%
df = pd.DataFrame(data,index = ind, columns=['m1','m2'])
df
# Out:
#         m1  m2
# a 2019  20  30
#   2020  40  50
# b 2019  33  44
#   2020  67  89
# c 2019  54  66
#   2020  78  99

# %%
df.index.names = ['name','year']

# %%
df
# Out:
#            m1  m2
# name year
# a    2019  20  30
#      2020  40  50
# b    2019  33  44
#      2020  67  89
# c    2019  54  66
#      2020  78  99

# %%
data1 = [[20,30,20,30],
       [40,50,40,50],
       [33,44,33,44],
       [67,89,67,89],
       [54,66,54,66],
       [78,99,78,99]]

# %%
ind1 = pd.MultiIndex.from_product([['a','b','c'],[2019,2020]])

# %%
col1 = pd.MultiIndex.from_product([['7th','8th'],['math','science']])

# %%
df1 = pd.DataFrame(data1, index=ind1, columns=col1)
df1
# Out:
#         7th          8th
#        math science math science
# a 2019   20      30   20      30
#   2020   40      50   40      50
# b 2019   33      44   33      44
#   2020   67      89   67      89
# c 2019   54      66   54      66
#   2020   78      99   78      99

# %%
df1.index.names = ['name','year']

# %%
df1
# Out:
#            7th          8th
#           math science math science
# name year
# a    2019   20      30   20      30
#      2020   40      50   40      50
# b    2019   33      44   33      44
#      2020   67      89   67      89
# c    2019   54      66   54      66
#      2020   78      99   78      99

# %%
df1.columns.names = ['Grade','subject']
df1
# Out:
# Grade      7th          8th
# subject   math science math science
# name year
# a    2019   20      30   20      30
#      2020   40      50   40      50
# b    2019   33      44   33      44
#      2020   67      89   67      89
# c    2019   54      66   54      66
#      2020   78      99   78      99

# %%
import pandas as pd

# %%
ind = pd.MultiIndex.from_product([[2019,2020],['q1','q2','q3']])

# %%
data = [[20,30],
       [40,50],
       [33,44],
       [67,89],
       [54,66],
       [78,99]]

# %%
df = pd.DataFrame(data,index = ind, columns=['Sales','Profit'])
df
# Out:
#          Sales  Profit
# 2019 q1     20      30
#      q2     40      50
#      q3     33      44
# 2020 q1     67      89
#      q2     54      66
#      q3     78      99
